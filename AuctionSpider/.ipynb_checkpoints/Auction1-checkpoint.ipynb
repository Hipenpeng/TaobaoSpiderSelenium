# %%
import requests
from lxml import etree
import re
import pandas as pd
import time
from bs4 import BeautifulSoup

# %%
ssrequest = requests.Session()
headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36'
                         ' (KHTML, like Gecko) Chrome/62.0.3202.89 Safari/537.36'
            }
response = ssrequest.get("https://www.scotchwhiskyauctions.com/auctions/",headers =headers)
# jd_cookies_dict


HTML=etree.HTML(response.text)

# %%
Auction_List = HTML.xpath('//*[@id="contentstart"]/div[2]/div/a')
action_list = []
for auction in Auction_List:
    auction_title = auction.xpath('./span/span/text()')[0]
    auction_date = auction.xpath('./span/span/text()')[1]
    auction_products = auction.xpath('./span/span/text()')[2]
    auction_link ='https://www.scotchwhiskyauctions.com/'+ auction.xpath('./@href')[0]
    auction_dic = {'auction_title':auction_title,'auction_date':auction_date,'auction_products':auction_products,'auction_link':auction_link}
    action_list.append(auction_dic)

# %%
auction_df = pd.DataFrame(action_list)
auction_df
# Out:
#              auction_title                auction_date  \
# 0        The 113th Auction    Ends on November 1, 2020
# 1        The 112th Auction    Ended on October 4, 2020
# 2        The 111th Auction  Ended on September 6, 2020
# 3        The 110th Auction     Ended on August 2, 2020
# 4        The 109th Auction       Ended on July 5, 2020
# ..                     ...                         ...
# 110      The Fifth Auction    Ended on August 29, 2011
# 111     The Fourth Auction     Ended on August 1, 2011
# 112      The Third Auction       Ended on July 4, 2011
# 113     The Second Auction       Ended on June 5, 2011
# 114  The Inaugural Auction        Ended on May 1, 2011
#
#                          auction_products  \
# 0    There are 8152 lots in this auction.
# 1    There are 7638 lots in this auction.
# 2    There are 7343 lots in this auction.
# 3    There are 6759 lots in this auction.
# 4    There are 5640 lots in this auction.
# ..                                    ...
# 110   There are 161 lots in this auction.
# 111   There are 132 lots in this auction.
# 112    There are 78 lots in this auction.
# 113    There are 94 lots in this auction.
# 114   There are 112 lots in this auction.
#
#                                           auction_link
# 0    https://www.scotchwhiskyauctions.com/auctions/...
# 1    https://www.scotchwhiskyauctions.com/auctions/...
# 2    https://www.scotchwhiskyauctions.com/auctions/...
# 3    https://www.scotchwhiskyauctions.com/auctions/...
# 4    https://www.scotchwhiskyauctions.com/auctions/...
# ..                                                 ...
# 110  https://www.scotchwhiskyauctions.com/auctions/...
# 111  https://www.scotchwhiskyauctions.com/auctions/...
# 112  https://www.scotchwhiskyauctions.com/auctions/...
# 113  https://www.scotchwhiskyauctions.com/auctions/...
# 114  https://www.scotchwhiskyauctions.com/auctions/...
#
# [115 rows x 4 columns]

# %%
def get_auction_product_data(auction_link,auction_product_num):
    pro_num_per_page = 5000
    total_page_num = int(int(auction_product_num)/pro_num_per_page)+2
    products_list = []
    for page_num in range(1,total_page_num):
        url_mod = '?page={0}&area=&sort=price&order=desc&perpage={1}'.format(page_num,pro_num_per_page)
        auction_page_link = auction_link+url_mod
        print(auction_page_link)
        response1 =  ssrequest.get(auction_page_link,headers =headers)
        Product_HTML = etree.HTML(response1.text)
        
        Production_List =  Product_HTML.xpath('//*[@id="contentstart"]/div[2]/div[3]/div/div[4]/a')
        for product in soup.select('.productsubcats.products > a'):
            product_title = product.select('.prodtitle')[0].string
            product_lot = product.select('.prodlot.priceline.curprice')[0].string
            product_lot = product_lot.split(' ')[2]
            try:
                product_price = product.select('.price')[0].string
            except IndexError:
                product_price = 'Item failed to meet reserve.'
            product_link = 'https://www.'+ product['href']
            product_dic = {'product_title':product_title,'product_lot':product_lot,'product_price':product_price,'product_link':product_link}
            products_list.append(product_dic)
            
#         for product in Production_List:
#             product_title = product.xpath('./span/span/text()')[0]
#             product_lot = product.xpath('./span/span[2]/span/text()')[0]
#             product_lot = product_lot.split(' ')[2]
#             try:
#                 product_price = product.xpath('./span/span[2]/span/span/span/text()')[0]
#             except:
#                 product_price = product.xpath('./span/span[2]/span/span/text()')[0]
#             product_link ='https://www.'+ product.xpath('./@href')[0]
#             product_dic = {'product_title':product_title,'product_lot':product_lot,'product_price':product_price,'product_link':product_link}
#             products_list.append(product_dic)

    return products_list

# %%
fist_to_csv = 1

# %%
for auction in auction_df.values[2:3]:
    auction_title = auction[0]
    auction_date = auction[1]
    auction_product_num = auction[2].split(' ')[2]
    auction_link = auction[3]
    product_list = get_auction_product_data(auction_link,auction_product_num)
    products_df = pd.DataFrame(product_list)
    auction_title = auction_title.split(' ')[1]
    products_df['auction_No'] = auction_title
    
    auction_date = auction_date.split(' ')[2:]
    products_df['auction_end_date'] = ' '.join(auction_date)
    
    products_df['auction_link'] = auction_link
#     if fist_to_csv == 1:
#         products_df.to_csv('product_data.csv',header =True,index =False)
#         fist_to_csv = 0 
#     else:
#         products_df.to_csv('product_data_v1.csv',header =False,index =False,mode = 'a')
#         print('存入成功')
# Out:
# https://www.scotchwhiskyauctions.com/auctions/152_the-111th-auction/?page=1&area=&sort=price&order=desc&perpage=5000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7b0b3ac9a885> in <module>
#       4     auction_product_num = auction[2].split(' ')[2]
#       5     auction_link = auction[3]
# ----> 6     product_list = get_auction_product_data(auction_link,auction_product_num)
#       7     products_df = pd.DataFrame(product_list)
#       8     auction_title = auction_title.split(' ')[1]
#
# <ipython-input-5-dec837d021ea> in get_auction_product_data(auction_link, auction_product_num)
#      11
#      12         Production_List =  Product_HTML.xpath('//*[@id="contentstart"]/div[2]/div[3]/div/div[4]/a')
# ---> 13         for product in soup.select('.productsubcats.products > a'):
#      14             product_title = product.select('.prodtitle')[0].string
#      15             product_lot = product.select('.prodlot.priceline.curprice')[0].string
#
# NameError: name 'soup' is not defined

# %%
products_df
