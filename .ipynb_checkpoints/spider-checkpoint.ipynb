# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import numpy as np
import time

# %%
def link_source(link):#链接分类，分为淘宝和天猫
    if link.find('taobao')>0:
        return 'tb'
    elif link.find('chaoshi')>0:
        return 'tm'
    else:
        return 'tm'
links_df = pd.read_excel('爬取链接.xlsx')
links_df['web'] = links_df['links'].apply(link_source)
links_df
# Out:
#                                                  links web
# 0    https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 1    https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 2    https://detail.tmall.com/item.htm?spm=a230r.1....  tm
# 3    https://detail.tmall.com/item.htm?spm=a1z10.3-...  tm
# 4    https://item.taobao.com/item.htm?spm=a1z10.3-c...  tb
# ..                                                 ...  ..
# 125  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 126  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 127  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 128  https://detail.tmall.com/item.htm?spm=a230r.1....  tm
# 129  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
#
# [130 rows x 2 columns]

# %%
browser = webdriver.Chrome()
# 打开淘宝登录先登录
browser.get("https://login.taobao.com/member/login.jhtml?spm=a21bo.2017.754894437.1.5af911d9q07jcU&f=top&redirectURL=https%3A%2F%2Fwww.taobao.com%2F")
# 定义js代码
script = "Object.defineProperty(navigator,'webdriver',{get: ()=> false,});"
# 执行js代码
browser.execute_script(script)#这样登录的时候就不会出现滑块

# %% [markdown]
# 淘宝链接

# %%
tb_df = links_df[links_df['web']=='tb']
tb_df
# Out:
#                                                  links web
# 0    https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 1    https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 4    https://item.taobao.com/item.htm?spm=a1z10.3-c...  tb
# 6    https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 9    https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# ..                                                 ...  ..
# 124  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 125  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 126  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 127  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
# 129  https://item.taobao.com/item.htm?spm=a230r.1.1...  tb
#
# [61 rows x 2 columns]

# %% [markdown]
# 天猫链接

# %%
tm_df = links_df[links_df['web']=='tm']
tm_df
# Out:
#                                                  links web
# 2    https://detail.tmall.com/item.htm?spm=a230r.1....  tm
# 3    https://detail.tmall.com/item.htm?spm=a1z10.3-...  tm
# 5    https://detail.tmall.com/item.htm?spm=a1z10.3-...  tm
# 7    https://detail.tmall.com/item.htm?spm=a220m.10...  tm
# 8    https://detail.tmall.com/item.htm?spm=a220m.10...  tm
# ..                                                 ...  ..
# 119  https://detail.tmall.hk/hk/item.htm?spm=a230r....  tm
# 120  https://detail.tmall.com/item.htm?spm=a230r.1....  tm
# 121  https://detail.tmall.com/item.htm?spm=a230r.1....  tm
# 123  https://chaoshi.detail.tmall.com/item.htm?id=6...  tm
# 128  https://detail.tmall.com/item.htm?spm=a230r.1....  tm
#
# [69 rows x 2 columns]

# %%
shopping_links_list =[]
title_list =[]
underline_price_list = []
prmote_price_list = []
activity_price_list =[]
activity_info_list = []
coupon_info_list = []
sales_list = []
comment_num_list = []
i=0
for link in tb_df['links']:
    browser.get(link)
    time.sleep( 4 )
    currentPageUrl = browser.current_url
    if currentPageUrl.find('tmall')>0:
        tm_df.append([{'links':currentPageUrl,'web':'tm'}])
        
    else:
        shopping_links_list.append(link)
        
        title = browser.find_element_by_xpath('//*[@id="J_Title"]/h3').text#标题
        title_list.append(title)

        underline_price = browser.find_element_by_xpath('//*[@id="J_StrPrice"]/em[2]').text#划线价
        underline_price_list.append(underline_price)

        try:
            prmote_price = browser.find_element_by_xpath('//*[@id="J_PromoPriceNum"]').text#促销价
        except NoSuchElementException:
            prmote_price = np.nan
        prmote_price_list.append(prmote_price)

        activity_price = browser.find_element_by_xpath('//*[@id="J_ActivityPrice"]').text#活动价
        activity_price_list.append(activity_price)

        try:
            activity_info = browser.find_element_by_xpath('//*[@id="J_PromoType"]').text#活动信息
        except NoSuchElementException:
            activity_info = np.nan
        activity_info_list.append(activity_info)

        coupon_info = browser.find_element_by_xpath('//*[@id="J_OtherDiscount"]/div').text#优惠券信息
        coupon_info_list.append(coupon_info)

        sales = browser.find_element_by_xpath('//*[@id="J_SellCounter"]').text#销量
        sales_list.append(sales)

        comment_num = browser.find_element_by_xpath('//*[@id="J_TabBar"]/li[2]/a/em').text#评论数
        comment_num_list.append(comment_num)
    
dic ={'商品链接':shopping_links_list,
    '商品标题':title_list,
     '划线价':underline_price_list,
     '活动价':activity_price_list,
     '促销价':prmote_price_list,
     '活动信息':activity_info_list,
     '优惠券信息':coupon_info_list,
     '月销量':sales_list,
     '累计评论':comment_num_list}
tb_info_df = pd.DataFrame(dic)

# %%
shopping_links_list =[]
title_list =[]
underline_price_list = []
prmote_price_list = []
activity_price_list =[]
activity_info_list = []
coupon_info_list = []
sales_list = []
comment_num_list = []
for link in tm_df['links'][29:]:
    browser.get(link)
    time.sleep(6)
    
    shopping_links_list.append(link)
    
    try:
        title = browser.find_element_by_xpath('//*[@id="J_DetailMeta"]/div[1]/div[1]/div/div[1]/h1').text#标题
    except NoSuchElementException:
        title='商品不存在'
    title_list.append(title)

    try:
        underline_price = browser.find_element_by_xpath('//*[@id="J_StrPriceModBox"]/dd/span[1]').text#划线价
    except NoSuchElementException:
        underline_price = np.nan
    underline_price_list.append(underline_price)
    
    try:
        prmote_price = browser.find_element_by_xpath('//*[@id="J_PromoPrice"]/dd/div/span').text#促销价
    except NoSuchElementException:
        prmote_price = np.nan
    prmote_price_list.append(prmote_price)

    try:
        activity_price = browser.find_element_by_xpath('//*[@id="J_ActivityPrice"]').text#活动价
    except NoSuchElementException:
        activity_price =np.nan
    activity_price_list.append(activity_price)
    
    try:
        activity_info = browser.find_element_by_xpath('//*[@id="J_DetailMeta"]/div[1]/div[1]/div/div[2]/dl[3]/div[1]/dd').text#活动信息
    except NoSuchElementException:
        activity_info = np.nan
    activity_info_list.append(activity_info)
    
    try:
        coupon_info = browser.find_element_by_xpath('//*[@id="J_DetailMeta"]/div[1]/div[1]/div/ul/li[3]/div/a').text#优惠券信息
    except NoSuchElementException:
        coupon_info =np.nan
    coupon_info_list.append(coupon_info)
    
    try:
        sales = browser.find_element_by_xpath('//*[@id="J_DetailMeta"]/div[1]/div[1]/div/ul/li[1]/div/span[2]').text#销量
    except NoSuchElementException:
        sales =np.nan
    sales_list.append(sales)
    
    try:
        comment_num = browser.find_element_by_xpath('//*[@id="J_ItemRates"]/div/span[2]').text#评论数
    except NoSuchElementException: 
        comment_num=np.nan
    comment_num_list.append(comment_num)
dic ={'商品链接':shopping_links_list,
    '商品标题':title_list,
     '划线价':underline_price_list,
     '活动价':activity_price_list,
     '促销价':prmote_price_list,
     '活动信息':activity_info_list,
     '优惠券信息':coupon_info_list,
     '月销量':sales_list,
     '累计评论':comment_num_list}
tm_info_df = pd.DataFrame(dic)

# %%
tm_info_df
# Out:
#                                                  商品链接  \
# 0   https://detail.tmall.com/item.htm?spm=a230r.1....
# 1   https://detail.tmall.com/item.htm?spm=a1z10.3-...
# 2   https://detail.tmall.com/item.htm?spm=a1z10.3-...
# 3   https://detail.tmall.com/item.htm?spm=a220m.10...
# 4   https://detail.tmall.com/item.htm?spm=a220m.10...
# ..                                                ...
# 64  https://detail.tmall.hk/hk/item.htm?spm=a230r....
# 65  https://detail.tmall.com/item.htm?spm=a230r.1....
# 66  https://detail.tmall.com/item.htm?spm=a230r.1....
# 67  https://chaoshi.detail.tmall.com/item.htm?id=6...
# 68  https://detail.tmall.com/item.htm?spm=a230r.1....
#
#                                       商品标题     划线价  活动价     促销价  \
# 0   WHISKY L Ardbeg阿贝雅柏雅伯10年单一麦芽威士忌苏格兰进口洋酒  472.00  NaN  405.00
# 1         Ardbeg阿贝雅柏雅伯阿德贝哥漩涡单一麦芽威士忌苏格兰进口洋酒  748.00  NaN  675.00
# 2      Bombay孟买蓝宝石金酒洋酒金酒金汤力杜松子酒琴酒原装进口750ml  150.00  NaN  118.00
# 3    孟买蓝宝石金酒 BOMBAY 杜松子酒鸡尾酒洋酒烈酒金汤力基酒 750ml  150.00  NaN   97.00
# 4         直营高颜值金汤力杜松子配柠檬苏打水不上头孟买蓝宝石金酒750ml  299.00  NaN  109.00
# ..                                     ...     ...  ...     ...
# 64      野格好入口新鲜日期35度力娇酒百搭红牛碳酸果汁口感柔顺700ml*2  798.00  NaN  336.00
# 65          醉鹅娘 德国进口洋酒野格圣鹿酒利口酒力娇酒正品行货700ml  198.00  NaN  138.00
# 66        【选赠品】德国进口洋酒野格圣鹿利口酒700ml力娇酒 鹿头酒正品  198.00  NaN  138.00
# 67  【进口】网红野格圣鹿正品行货700ml+RIO锐澳微醺白桃味330ml*2瓶          NaN  138.00
# 68       【定时送】正品野格利口酒700ml 德国野格圣鹿力娇酒进口洋酒鹿头  189.00  NaN  138.00
#
#                                活动信息     优惠券信息    月销量   累计评论
# 0                               NaN  送天猫积分202     59    135
# 1                               NaN  送天猫积分337     27    137
# 2                         满236元减20元   送天猫积分59    786   1305
# 3                 满1件,送任意1件赠品（赠完即止）   送天猫积分48    232   2223
# 4                               NaN   送天猫积分10    167    296
# ..                              ...       ...    ...    ...
# 64                              NaN       NaN     96     75
# 65  满1件,送任意1件赠品（赠完即止）；满2件,送任意2件赠品（…   送天猫积分69  8500+  49387
# 66  满1件,送任意1件赠品（赠完即止）；满2件,送任意2件赠品（…   送天猫积分69   1698  23776
# 67                              NaN   送天猫积分13    258   3076
# 68              满138元,送任意2件赠品（赠完即止）   送天猫积分69    331   3723
#
# [69 rows x 9 columns]

# %%
info_df = pd.concat([tb_info_df,tm_info_df],axis=0)#两个拼接起来
info_df[info_df['划线价']=='']=np.nan
info_df.reset_index(inplace=True)
info_df.drop(columns=['index'],inplace= True)
info_df.fillna('-')
info_df.to_csv('info.csv')#保存为csv
